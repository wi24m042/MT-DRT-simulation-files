# %%
import xml.etree.ElementTree as ET

# %%
routes_filepath_list = ["D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_offseason_bus_modded_with_parents.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_offseason_taxi_modded_with_parents.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_offseason_taxi_modded_with_parents_w10.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_offseason_taxi_modded_with_parents_w15.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_winter_bus_modded_with_parents.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_winter_bus_taxi_modded_with_parents.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_winter_bus_taxi_modded_with_parents_w10.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_winter_bus_taxi_modded_with_parents_w15.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_summer_bus_modded_with_parents.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_summer_bus_taxi_modded_with_parents.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_summer_bus_taxi_modded_with_parents_w10.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\01_schools\\persontrips_maloja_school_resolved_summer_bus_taxi_modded_with_parents_w15.rou.xml"]

# %%
for routes_filepath in routes_filepath_list:

    routes_file_xmltree = ET.parse(routes_filepath)
    routes_file_xmlroot = routes_file_xmltree.getroot()

    print(routes_filepath)

    pc = 0
    pptc = 0
    pptr = 0

    for person in list(routes_file_xmlroot):
        pc += 1
        for leg in person:
            if leg.tag == "ride":
                pptr+=1
                if "intended" in leg.attrib:
                    pptc += 1
                    break
    print("person count: " + str(pc) + " persons | persons with rides: " + str(pptr) + " | persons with public transportation: " + str(pptc))
# Out:
# D:\Dokumente\sumo\maloja\01_schools\persontrips_maloja_school_resolved_offseason_bus_modded_with_parents.rou.xml
# person count: 408 persons | persons with rides: 408 | persons with public transportation: 408
# D:\Dokumente\sumo\maloja\01_schools\persontrips_maloja_school_resolved_offseason_taxi_modded_with_parents.rou.xml
# person count: 408 persons | persons with rides: 404 | persons with public transportation: 0
# D:\Dokumente\sumo\maloja\01_schools\persontrips_maloja_school_resolved_offseason_taxi_modded_with_parents_w10.rou.xml
# person count: 408 persons | persons with rides: 380 | persons with public transportation: 0
# D:\Dokumente\sumo\maloja\01_schools\persontrips_maloja_school_resolved_offseason_taxi_modded_with_parents_w15.rou.xml
# person count: 408 persons | persons with rides: 348 | persons with public transportation: 0
# D:\Dokumente\sumo\maloja\01_schools\persontrips_maloja_school_resolved_winter_bus_modded_with_parents.rou.xml
# ...
