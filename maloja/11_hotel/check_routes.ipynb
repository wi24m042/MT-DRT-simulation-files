# %%
import xml.etree.ElementTree as ET

# %%
routes_filepath_list = ["D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_offseason_bus_modded.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_offseason_taxi.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_offseason_taxi_w10.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_offseason_taxi_w15.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_summer_bus.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_summer_bus_taxi.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_winter_bus.rou.xml",
                        "D:\\Dokumente\\sumo\\maloja\\11_hotel\\persontrips_maloja_hotel_resolved_winter_bus_taxi.rou.xml"]

# %%
for routes_filepath in routes_filepath_list:

    routes_file_xmltree = ET.parse(routes_filepath)
    routes_file_xmlroot = routes_file_xmltree.getroot()

    print(routes_filepath)

    pc = 0
    pptc = 0
    pptr = 0

    for person in list(routes_file_xmlroot):
        pc += 1
        for leg in person:
            if leg.tag == "ride":
                pptr+=1
                if "intended" in leg.attrib:
                    pptc += 1
                    break
    print("person count: " + str(pc) + " persons | persons with rides: " + str(pptr) + " | persons with public transportation: " + str(pptc))
# Out:
# D:\Dokumente\sumo\maloja\11_hotel\persontrips_maloja_hotel_resolved_offseason_bus_modded.rou.xml
# person count: 428 persons | persons with rides: 428 | persons with public transportation: 428
# D:\Dokumente\sumo\maloja\11_hotel\persontrips_maloja_hotel_resolved_offseason_taxi.rou.xml
# person count: 428 persons | persons with rides: 426 | persons with public transportation: 0
# D:\Dokumente\sumo\maloja\11_hotel\persontrips_maloja_hotel_resolved_offseason_taxi_w10.rou.xml
# person count: 428 persons | persons with rides: 410 | persons with public transportation: 0
# D:\Dokumente\sumo\maloja\11_hotel\persontrips_maloja_hotel_resolved_offseason_taxi_w15.rou.xml
# person count: 428 persons | persons with rides: 387 | persons with public transportation: 0
# D:\Dokumente\sumo\maloja\11_hotel\persontrips_maloja_hotel_resolved_summer_bus.rou.xml
# person count: 13804 persons | persons with rides: 10005 | persons with public transportation: 10005
# ...
