# %%
import xml.etree.ElementTree as ET

# %%
#persontrips_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_offseason_taxi.rou.xml"
#output_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_offseason_taxi.rou.xml"
#persontrips_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_offseason_taxi_w10.rou.xml"
#output_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_offseason_taxi_w10.rou.xml"
#persontrips_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_offseason_taxi_w15.rou.xml"
#output_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_offseason_taxi_w15.rou.xml"
#persontrips_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_summer_bus_taxi.rou.xml"
#output_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_summer_bus_taxi.rou.xml"
persontrips_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_winter_bus_taxi.rou.xml"
output_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_winter_bus_taxi.rou.xml"

# %%
persontrips_file_xmltree = ET.parse(persontrips_filepath)
persontrips_file_xmlroot = persontrips_file_xmltree.getroot()

# %%
for person_child in list(persontrips_file_xmlroot):
    person_child.set("id", "tn" + str(person_child.get("id")))

# %%
persontrips_file_xmltree.write(output_filepath)
