# %%
import xml.etree.ElementTree as ET
import copy

# %%
persontrips_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_summer.xml"
persontrips_filepath_output = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_summer_modded.xml"
routes_filepath = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_summer_bus.rou.xml"
routes_filepath_output = "D:\\Dokumente\\sumo\\maloja\\12_non_hotel\\persontrips_maloja_non_hotel_resolved_summer_bus_modded.rou.xml"

# %%
demand_arriving_leaving = {
    "taz_St_Moritz_Sink-taz_Bregaglia": 12,
    "taz_St_Moritz_Sink-taz_Silvaplana": 9,
    "taz_St_Moritz_Sink-taz_Sils_Engadin": 20,
    "taz_St_Moritz_Sink-taz_St_Moritz": 96
}

demand_shopping = {
    "taz_Bregaglia-taz_shopping_bregaglia_vicosoprano": 8,
    "taz_Silvaplana-taz_shopping_silvaplana": 6,
    "taz_Sils_Engadin-taz_shopping_sils_engadin": 14,
    "taz_St_Moritz-taz_shopping_st_moritz_west": 64
}

demand_activities = {
    "taz_Bregaglia-taz_Cable_Car_Albigna": 11,
    "taz_Bregaglia-taz_Bregaglia_Summer": 11,
    "taz_Bregaglia-taz_Sils_Engadin_Summer": 11,
    "taz_Bregaglia-taz_Silvaplana_Summer": 11,
    "taz_Bregaglia-taz_St_Moritz_Summer": 11,
    "taz_Bregaglia-taz_ski_corviglia_piz_nair_st_moritz": 11,
    "taz_Bregaglia-taz_ski_corvatsch_sils_im_engadin": 11,
    
    "taz_Bregaglia-taz_St_Moritz": 16,
    "taz_Bregaglia-taz_Bregaglia": 16,
    "taz_Bregaglia-taz_Silvaplana": 16,
    "taz_Bregaglia-taz_Sils_Engadin": 16,
    "taz_Bregaglia-taz_St_Moritz_Sink": 16,

    "taz_Silvaplana-taz_Cable_Car_Albigna": 11,
    "taz_Silvaplana-taz_Bregaglia_Summer": 11,
    "taz_Silvaplana-taz_Sils_Engadin_Summer": 11,
    "taz_Silvaplana-taz_Silvaplana_Summer": 11,
    "taz_Silvaplana-taz_St_Moritz_Summer": 11,
    "taz_Silvaplana-taz_ski_corviglia_piz_nair_st_moritz": 11,
    "taz_Silvaplana-taz_ski_corvatsch_silvaplana": 11,

    "taz_Silvaplana-taz_St_Moritz": 16,
    "taz_Silvaplana-taz_Bregaglia": 16,
    "taz_Silvaplana-taz_Silvaplana": 16,
    "taz_Silvaplana-taz_Sils_Engadin": 16,
    "taz_Silvaplana-taz_St_Moritz_Sink": 16,
    
    "taz_Sils_Engadin-taz_Cable_Car_Albigna": 32,
    "taz_Sils_Engadin-taz_Bregaglia_Summer": 32,
    "taz_Sils_Engadin-taz_Sils_Engadin_Summer": 32,
    "taz_Sils_Engadin-taz_Silvaplana_Summer": 32,
    "taz_Sils_Engadin-taz_St_Moritz_Summer": 32,
    "taz_Sils_Engadin-taz_ski_corviglia_piz_nair_st_moritz": 32,
    "taz_Sils_Engadin-taz_ski_corvatsch_sils_im_engadin": 32,

    "taz_Sils_Engadin-taz_St_Moritz": 45,
    "taz_Sils_Engadin-taz_Bregaglia": 45,
    "taz_Sils_Engadin-taz_Silvaplana": 45,
    "taz_Sils_Engadin-taz_Sils_Engadin": 45,
    "taz_Sils_Engadin-taz_St_Moritz_Sink": 45,
    
    "taz_St_Moritz-taz_Cable_Car_Albigna": 92,
    "taz_St_Moritz-taz_Bregaglia_Summer": 92,
    "taz_St_Moritz-taz_Sils_Engadin_Summer": 92,
    "taz_St_Moritz-taz_Silvaplana_Summer": 92,
    "taz_St_Moritz-taz_St_Moritz_Summer": 92,
    "taz_St_Moritz-taz_ski_corviglia_piz_nair_st_moritz": 92,
    "taz_St_Moritz-taz_ski_corvatsch_silvaplana": 92,

    "taz_St_Moritz-taz_St_Moritz": 128,
    "taz_St_Moritz-taz_Bregaglia": 128,
    "taz_St_Moritz-taz_Silvaplana": 128,
    "taz_St_Moritz-taz_Sils_Engadin": 128,
    "taz_St_Moritz-taz_St_Moritz_Sink": 128,
}

# %%
demand_non_hotel_arriving = copy.deepcopy(demand_arriving_leaving)
demand_non_hotel_leaving = copy.deepcopy(demand_arriving_leaving)

# %%
demand_shopping_from_non_hotel = copy.deepcopy(demand_shopping)
demand_shopping_to_non_hotel = copy.deepcopy(demand_shopping)

# %%
demand_from_non_hotel = copy.deepcopy(demand_activities)
demand_to_non_hotel = copy.deepcopy(demand_activities)

# %%
persontrips_file_xmltree = ET.parse(persontrips_filepath)
persontrips_file_xmlroot = persontrips_file_xmltree.getroot()

# %%
routes_file_xmltree = ET.parse(routes_filepath)
routes_file_xmlroot = routes_file_xmltree.getroot()

# %%
for trip_child in list(routes_file_xmlroot):
    has_ride = False
    for stage_child in list(trip_child):
        if stage_child.tag == "ride":
            if "intended" in stage_child.attrib:
                has_ride = True
                break

    if has_ride == True:
        for persontrip_child in list(persontrips_file_xmlroot):
            if trip_child.get("id") == persontrip_child.get("id"):
                demand_ft_key = str(persontrip_child[0].get("fromTaz")) + "-" + str(persontrip_child[0].get("toTaz"))
                demand_tf_key = str(persontrip_child[0].get("toTaz")) + "-" + str(persontrip_child[0].get("fromTaz"))

                if 36000 <= float(str(trip_child.get("depart"))) <= 43200 and demand_tf_key in demand_non_hotel_leaving and demand_non_hotel_leaving[demand_tf_key] > 0:
                    demand_non_hotel_leaving[demand_tf_key] = demand_non_hotel_leaving[demand_tf_key] - 1
                    break
                elif 43200 <= float(str(trip_child.get("depart"))) <= 50400 and demand_ft_key in demand_non_hotel_arriving and demand_non_hotel_arriving[demand_ft_key] > 0:
                    demand_non_hotel_arriving[demand_ft_key] = demand_non_hotel_arriving[demand_ft_key] - 1
                    break
                elif 50400 <= float(str(trip_child.get("depart"))) <= 64800 and demand_ft_key in demand_shopping_from_non_hotel and demand_shopping_from_non_hotel[demand_ft_key] > 0:
                    demand_shopping_from_non_hotel[demand_ft_key] = demand_shopping_from_non_hotel[demand_ft_key] - 1
                    break
                elif 54000 <= float(str(trip_child.get("depart"))) <= 66600 and demand_tf_key in demand_shopping_to_non_hotel and demand_shopping_to_non_hotel[demand_tf_key] > 0:
                    demand_shopping_to_non_hotel[demand_tf_key] = demand_shopping_to_non_hotel[demand_tf_key] - 1
                    break
                elif demand_ft_key in demand_from_non_hotel and demand_from_non_hotel[demand_ft_key] > 0:
                    demand_from_non_hotel[demand_ft_key] = demand_from_non_hotel[demand_ft_key] - 1
                    break
                elif demand_tf_key in demand_to_non_hotel and demand_to_non_hotel[demand_tf_key] > 0:
                    demand_to_non_hotel[demand_tf_key] = demand_to_non_hotel[demand_tf_key] - 1
                    break
                else:
                    routes_file_xmlroot.remove(trip_child)
                    break

    if has_ride == False:
        routes_file_xmlroot.remove(trip_child)

# %%
demand_non_hotel_leaving
# Out:
# {'taz_St_Moritz_Sink-taz_Bregaglia': 0,
#  'taz_St_Moritz_Sink-taz_Silvaplana': 0,
#  'taz_St_Moritz_Sink-taz_Sils_Engadin': 0,
#  'taz_St_Moritz_Sink-taz_St_Moritz': 0}

# %%
demand_non_hotel_arriving
# Out:
# {'taz_St_Moritz_Sink-taz_Bregaglia': 0,
#  'taz_St_Moritz_Sink-taz_Silvaplana': 0,
#  'taz_St_Moritz_Sink-taz_Sils_Engadin': 0,
#  'taz_St_Moritz_Sink-taz_St_Moritz': 0}

# %%
demand_shopping_from_non_hotel
# Out:
# {'taz_Bregaglia-taz_shopping_bregaglia_vicosoprano': 0,
#  'taz_Silvaplana-taz_shopping_silvaplana': 0,
#  'taz_Sils_Engadin-taz_shopping_sils_engadin': 0,
#  'taz_St_Moritz-taz_shopping_st_moritz_west': 0}

# %%
demand_shopping_to_non_hotel
# Out:
# {'taz_Bregaglia-taz_shopping_bregaglia_vicosoprano': 0,
#  'taz_Silvaplana-taz_shopping_silvaplana': 0,
#  'taz_Sils_Engadin-taz_shopping_sils_engadin': 0,
#  'taz_St_Moritz-taz_shopping_st_moritz_west': 0}

# %%
demand_from_non_hotel
# Out:
# {'taz_Bregaglia-taz_Cable_Car_Albigna': 0,
#  'taz_Bregaglia-taz_Bregaglia_Summer': 0,
#  'taz_Bregaglia-taz_Sils_Engadin_Summer': 0,
#  'taz_Bregaglia-taz_Silvaplana_Summer': 0,
#  'taz_Bregaglia-taz_St_Moritz_Summer': 0,
#  'taz_Bregaglia-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_Bregaglia-taz_ski_corvatsch_sils_im_engadin': 0,
#  'taz_Bregaglia-taz_St_Moritz': 0,
#  'taz_Bregaglia-taz_Bregaglia': 0,
#  'taz_Bregaglia-taz_Silvaplana': 0,
#  'taz_Bregaglia-taz_Sils_Engadin': 0,
#  'taz_Bregaglia-taz_St_Moritz_Sink': 0,
#  'taz_Silvaplana-taz_Cable_Car_Albigna': 0,
#  'taz_Silvaplana-taz_Bregaglia_Summer': 0,
#  'taz_Silvaplana-taz_Sils_Engadin_Summer': 0,
#  'taz_Silvaplana-taz_Silvaplana_Summer': 0,
#  'taz_Silvaplana-taz_St_Moritz_Summer': 0,
#  'taz_Silvaplana-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_Silvaplana-taz_ski_corvatsch_silvaplana': 0,
#  'taz_Silvaplana-taz_St_Moritz': 0,
#  'taz_Silvaplana-taz_Bregaglia': 0,
#  'taz_Silvaplana-taz_Silvaplana': 0,
#  'taz_Silvaplana-taz_Sils_Engadin': 0,
#  'taz_Silvaplana-taz_St_Moritz_Sink': 0,
#  'taz_Sils_Engadin-taz_Cable_Car_Albigna': 0,
#  'taz_Sils_Engadin-taz_Bregaglia_Summer': 0,
#  'taz_Sils_Engadin-taz_Sils_Engadin_Summer': 0,
#  'taz_Sils_Engadin-taz_Silvaplana_Summer': 0,
#  'taz_Sils_Engadin-taz_St_Moritz_Summer': 0,
#  'taz_Sils_Engadin-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_Sils_Engadin-taz_ski_corvatsch_sils_im_engadin': 0,
#  'taz_Sils_Engadin-taz_St_Moritz': 0,
#  'taz_Sils_Engadin-taz_Bregaglia': 0,
#  'taz_Sils_Engadin-taz_Silvaplana': 0,
#  'taz_Sils_Engadin-taz_Sils_Engadin': 0,
#  'taz_Sils_Engadin-taz_St_Moritz_Sink': 0,
#  'taz_St_Moritz-taz_Cable_Car_Albigna': 0,
#  'taz_St_Moritz-taz_Bregaglia_Summer': 0,
#  'taz_St_Moritz-taz_Sils_Engadin_Summer': 0,
#  'taz_St_Moritz-taz_Silvaplana_Summer': 0,
#  'taz_St_Moritz-taz_St_Moritz_Summer': 0,
#  'taz_St_Moritz-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_St_Moritz-taz_ski_corvatsch_silvaplana': 0,
#  'taz_St_Moritz-taz_St_Moritz': 0,
#  'taz_St_Moritz-taz_Bregaglia': 0,
#  'taz_St_Moritz-taz_Silvaplana': 0,
#  'taz_St_Moritz-taz_Sils_Engadin': 0,
#  'taz_St_Moritz-taz_St_Moritz_Sink': 0}

# %%
demand_to_non_hotel
# Out:
# {'taz_Bregaglia-taz_Cable_Car_Albigna': 0,
#  'taz_Bregaglia-taz_Bregaglia_Summer': 0,
#  'taz_Bregaglia-taz_Sils_Engadin_Summer': 0,
#  'taz_Bregaglia-taz_Silvaplana_Summer': 0,
#  'taz_Bregaglia-taz_St_Moritz_Summer': 0,
#  'taz_Bregaglia-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_Bregaglia-taz_ski_corvatsch_sils_im_engadin': 0,
#  'taz_Bregaglia-taz_St_Moritz': 0,
#  'taz_Bregaglia-taz_Bregaglia': 0,
#  'taz_Bregaglia-taz_Silvaplana': 0,
#  'taz_Bregaglia-taz_Sils_Engadin': 0,
#  'taz_Bregaglia-taz_St_Moritz_Sink': 0,
#  'taz_Silvaplana-taz_Cable_Car_Albigna': 0,
#  'taz_Silvaplana-taz_Bregaglia_Summer': 0,
#  'taz_Silvaplana-taz_Sils_Engadin_Summer': 0,
#  'taz_Silvaplana-taz_Silvaplana_Summer': 0,
#  'taz_Silvaplana-taz_St_Moritz_Summer': 0,
#  'taz_Silvaplana-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_Silvaplana-taz_ski_corvatsch_silvaplana': 0,
#  'taz_Silvaplana-taz_St_Moritz': 0,
#  'taz_Silvaplana-taz_Bregaglia': 0,
#  'taz_Silvaplana-taz_Silvaplana': 0,
#  'taz_Silvaplana-taz_Sils_Engadin': 0,
#  'taz_Silvaplana-taz_St_Moritz_Sink': 0,
#  'taz_Sils_Engadin-taz_Cable_Car_Albigna': 0,
#  'taz_Sils_Engadin-taz_Bregaglia_Summer': 0,
#  'taz_Sils_Engadin-taz_Sils_Engadin_Summer': 0,
#  'taz_Sils_Engadin-taz_Silvaplana_Summer': 0,
#  'taz_Sils_Engadin-taz_St_Moritz_Summer': 0,
#  'taz_Sils_Engadin-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_Sils_Engadin-taz_ski_corvatsch_sils_im_engadin': 0,
#  'taz_Sils_Engadin-taz_St_Moritz': 0,
#  'taz_Sils_Engadin-taz_Bregaglia': 0,
#  'taz_Sils_Engadin-taz_Silvaplana': 0,
#  'taz_Sils_Engadin-taz_Sils_Engadin': 0,
#  'taz_Sils_Engadin-taz_St_Moritz_Sink': 0,
#  'taz_St_Moritz-taz_Cable_Car_Albigna': 0,
#  'taz_St_Moritz-taz_Bregaglia_Summer': 0,
#  'taz_St_Moritz-taz_Sils_Engadin_Summer': 0,
#  'taz_St_Moritz-taz_Silvaplana_Summer': 0,
#  'taz_St_Moritz-taz_St_Moritz_Summer': 0,
#  'taz_St_Moritz-taz_ski_corviglia_piz_nair_st_moritz': 0,
#  'taz_St_Moritz-taz_ski_corvatsch_silvaplana': 0,
#  'taz_St_Moritz-taz_St_Moritz': 0,
#  'taz_St_Moritz-taz_Bregaglia': 0,
#  'taz_St_Moritz-taz_Silvaplana': 0,
#  'taz_St_Moritz-taz_Sils_Engadin': 0,
#  'taz_St_Moritz-taz_St_Moritz_Sink': 0}

# %%
for persontrip_child in list(persontrips_file_xmlroot):
    persontrip_in_routes = False
    for trip_child in list(routes_file_xmlroot):
        if trip_child.get("id") == persontrip_child.get("id"):
            persontrip_in_routes = True
            break
    
    if persontrip_in_routes == False:
        persontrips_file_xmlroot.remove(persontrip_child)

# %%
persontrips_file_xmltree.write(persontrips_filepath_output)
routes_file_xmltree.write(routes_filepath_output)
